# %% [markdown]
# # Neural Networks: Representation

# %% [markdown]
# ### Neurons and the Brain
#
# - Origins of Neural Networks: Algorithms that try to mimic the human brain. Was very widely used in the 80s and early 90s; popularity diminished in the late 90s.
# - There has been a recent resurgence and is now the state-of-the-art technique for many machine learning applications.

# %% [markdown]
# ### Model Representation I
#
# - Neuron Model: Logistic Unit
#     - $x_0$ is the bias unit
#     - The Sigmoid (logistic) **activation function** is another term for the non-linearity $g(z)$
#     - Parameters are often called **weights** in neural network models
#     - The first layer of the neural network is called the **input layer**
#     - The final layer is called the **output layer** because it outputs the final value computed by the hypothesis
#     - The middle layer(s) is called the **hidden layer**
# - $a_i^{(j)}$ = "activation" of the unit $i$ in layer $j$
# - $\theta^{(j)}$ = matrix of weights controlling fucntion mapping from layer $j$ to layer $j + 1$
#     - $a_1^{(2)} = g(\theta_{10}^{(1)}x_0 + \theta_{11}^{(1)}x_1 + \theta_{12}^{(1)}x_2 + \theta_{13}^{(1)}x_3)$
#     - $a_2^{(2)} = g(\theta_{20}^{(1)}x_0 + \theta_{21}^{(1)}x_1 + \theta_{22}^{(1)}x_2 + \theta_{23}^{(1)}x_3)$
#     - $a_3^{(2)} = g(\theta_{30}^{(1)}x_0 + \theta_{31}^{(1)}x_1 + \theta_{32}^{(1)}x_2 + \theta_{33}^{(1)}x_3)$
#     - $h_\theta(x) = a_1^{(3)} = g(\theta_{10}^{(2)}a_0^{(2)} + \theta_{11}^{(2)}a_1^{(2)} + \theta_{12}^{(2)}a_2^{(2)} + \theta_{13}^{(2)}a_3^{(2)})$
# - if network has $s_j$ units in layer $j$, $s_j + 1$ units in layer $j+1$, then $\theta^{(j)}$ will be of dimension $s_{j+1}$ x $(s_j+1)$
#
# ![image.png](attachment:image.png)
#
# ### Model Representation II
#
# - $x = \begin{bmatrix} x_0 \\ x_1 \\ x_2 \\ x_3 \end{bmatrix}$ $z^{(2)} = \begin{bmatrix} z_1^{(2)} \\ z_2^{(2)} \\ z_3^{(2)}\end{bmatrix}$
# - $z^{(2)} = \theta^{(1)}x$
# - $a^{(2)} = g(z^{(2)})$
# - add bias unit ($a_0^{(2)} = 1$)
#     - $z^{(3)} = \theta^{(2)}a^{(2)}$
#     - $h_\theta(x) = a^{(3)} = g(z^{(3)})$
# - this process is also called **forward propogation**
#
# ### Examples and Intuitions I
# - The first example below is the logical AND operator using neural networks followed by the logical OR function:
# ![image-2.png](attachment:image-2.png)
#
# ### Examples and Intuitions II
# ![image-3.png](attachment:image-3.png)
